# %%
import cv2
import os

import torch
import numpy as np
import pandas as pd
from PIL import Image
from glob import glob

import matplotlib.pyplot as plt

from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.checkpoint import checkpoint

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def display_image_with_mask(image: torch.tensor, mask: np.ndarray, alpha: float = 0.5):
    """
    Display a grayscale image with a binary mask overlaid.

    Parameters:
    - image: 2D tensor for a scan
    - mask:  2D numpy array of same shape with binary values (0 or 1).
    - alpha: float transparency for mask overlay.
    """
    plt.figure()
    plt.imshow(image, cmap='gray')
    plt.imshow(mask, alpha=alpha)
    plt.axis('off')
    plt.show()

# %%
# This class stores a scan slice image and its associated mask
class ScanSlice:
    def __init__(self, file_path, shape, transform=None):
        self.file_path = file_path
        self.transform = transform
        self.shape = shape

        # format the file name properly
        case_path = file_path.split('/')
        slice_name = case_path[-1].split('_')

        # name is the name in the train.csv file
        # original shape is the shape of the raw image before transform
        self.name = f"{case_path[-3]}_slice_{slice_name[1]}"
        self.original_shape = (int(slice_name[2]), int(slice_name[3]))

        # apply a default mask
        self.mask = np.zeros(self.shape, dtype=np.uint8)
        self.masks = {"stomach": np.zeros(self.shape, dtype=np.uint8),
                      "small_bowel": np.zeros(self.shape, dtype=np.uint8),
                      "large_bowel": np.zeros(self.shape, dtype=np.uint8)}

        # init the mask values that we will use
        self.mask_values = {"large_bowel": 1, "small_bowel": 2, "stomach": 3}

    def features(self, device="cpu", dtype=torch.float):
        # load image into memory
        img_data = cv2.imread(self.file_path, cv2.IMREAD_UNCHANGED)

        # format the data accordingly
        result = self.transform(img_data)
        result = result.to(dtype=dtype)
        result.to(device)

        return result

    def decode_rle(self, rle, label):
        # make sure the rle is not empty
        if not rle or (type(rle) is not str and np.isnan(rle)) or rle.strip() == "":
            return

        s = list(map(int, rle.strip().split()))
        starts, lengths = s[::2], s[1::2]
        starts = np.array(starts)
        ends = starts + lengths

        mask = np.zeros(self.original_shape[0] * self.original_shape[1], dtype=np.uint8)
        for start, end in zip(starts, ends):
            mask[start:end] = 1

        mask = cv2.resize(mask.reshape(self.original_shape), self.shape, interpolation=cv2.INTER_NEAREST)
        self.masks[label] = mask

        self.mask[mask == 1] = self.mask_values[label]

        allowed = {0, 1, 2, 3}
        unique_vals = np.unique(mask)

        if not set(unique_vals).issubset(allowed):
            raise Exception("An invalid value was found in a sample mask")


class MRIData(Dataset):
    def __init__(self, transform, slice_shape, device="cpu"):
        self.slices = dict()
        self.slice_index = list()

        self.device = device
        self.transform = transform
        self.slice_shape = slice_shape

        self.read_slice_data()
        self.read_rles()

    def __getitem__(self, idx):
        if type(idx) == str:
            return self.slices[idx].features(device=self.device), self.slices[idx].mask.astype(np.int64)
        return self.slice_index[idx].features(device=self.device), self.slice_index[idx].mask.astype(np.int64)

    def __len__(self):
        return len(self.slices)

    def get_slice(self, idx):
        if type(idx) == str:
            return self.slices[idx]
        return self.slice_index[idx]

    def read_slice_data(self):
        # get all of the slice paths
        slices = glob(f"{os.getcwd()}/gi-tract-data/train/*/*/scans/slice_*")
        slices = [slice.replace("\\", "/") for slice in slices]

        # create a slice object for every slice
        for slice_path in slices:
            ss = ScanSlice(slice_path, self.slice_shape, self.transform)
            self.slice_index.append(ss)
            self.slices[ss.name] = ss

    def read_rles(self):
        # open the train.csv file
        train_csv_path = f"{os.getcwd()}/gi-tract-data/train.csv"
        rle_file = pd.read_csv(train_csv_path)

        # give each slice its rle
        for i in range(0, len(rle_file)):
            slice_name, label, rle = rle_file.iloc[i]
            self.slices[slice_name].decode_rle(rle, label)

    def display_image_with_mask(self, idx):
        img, mask = self[idx]
        plt.figure()
        plt.imshow(img.squeeze(), cmap='gray')
        plt.imshow(mask, alpha=0.5)
        plt.axis('off')
        plt.show()

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((256, 256))
])

mrid = MRIData(transform, (256, 256), device=device)
training_data = Subset(mrid, list(range(3000)))
train_loader= DataLoader(training_data, batch_size=16, shuffle=True)

# %%
mrid.display_image_with_mask("case77_day20_slice_0115")

# %%
class DiceLoss(nn.Module):
    """
    Multi‑class Dice loss.
    Expects:
      - logits: (B, C, H, W) raw network outputs
      - targets: (B, H, W) integer class labels in [0..C-1]
    """
    def __init__(self, smooth: float = 1e-5):
        super().__init__()
        self.smooth = smooth

    def forward(self, logits: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
        # Number of classes from logits shape
        num_classes = logits.shape[1]

        # Convert to probabilities
        probs = F.softmax(logits, dim=1)

        # One‑hot encode targets to shape (B, C, H, W)
        with torch.no_grad():
            targets_one_hot = F.one_hot(targets, num_classes)  # (B, H, W, C)
            targets_one_hot = targets_one_hot.permute(0, 3, 1, 2).float()

        # Compute per‑class Dice score
        dims = (0, 2, 3)  # sum over batch & spatial dims
        intersection = torch.sum(probs * targets_one_hot, dims)
        cardinality  = torch.sum(probs + targets_one_hot, dims)
        dice_score   = (2. * intersection + self.smooth) / (cardinality + self.smooth)

        # Dice loss is 1 – mean Dice score across classes
        return 1. - dice_score.mean()

class CombinedLoss(nn.Module):
    """
    α * CrossEntropy + (1-α) * DiceLoss
    """
    def __init__(self, alpha: float = 0.5, weight: torch.Tensor = None, ignore_index: int = -100):
        """
        Args:
          alpha       – weight for the CrossEntropy term (in [0,1])
          weight      – optional tensor of shape (C,) to weight classes in CE
          ignore_index– optional index to ignore in CE and Dice
        """
        super().__init__()
        self.alpha = alpha
        self.ce    = nn.CrossEntropyLoss(weight=weight, ignore_index=ignore_index)
        self.dice  = DiceLoss()

    def forward(self, logits: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
        """
        logits: (B, C, H, W)
        targets: (B, H, W)
        """
        loss_ce   = self.ce(logits, targets)
        loss_dice = self.dice(logits, targets)
        return self.alpha * loss_ce + (1. - self.alpha) * loss_dice

# %%
# Define a double convolution block: (Conv -> BatchNorm -> ReLU) * 2
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)

# Downsampling block: MaxPool then DoubleConv
class Down(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Down, self).__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)

class BottleneckResBlock(nn.Module):
    def __init__(self, in_channels, dropout_prob=0.3):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, in_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Dropout2d(p=dropout_prob),
            nn.Conv2d(in_channels, in_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(in_channels)
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        return self.relu(x + self.conv(x))

# Upsampling block: Upsample (or ConvTranspose2d) then DoubleConv.
class Up(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Up, self).__init__()
        self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        # x1 is from the previous layer (decoder), x2 is from the encoder (skip connection)
        x1 = self.up(x1)
        # pad x1 if necessary to match dimensions of x2
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]
        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        # concatenate along the channel dimension
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)

# Final output convolution to reduce the number of channels to the desired number of classes.
class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)

# %%
# this reduces memory problems with cuda
torch.cuda.empty_cache()

# %%
# Define the U-Net architecture
class UNet(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes

        self.inc = DoubleConv(n_channels, 64)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        self.down3 = Down(256, 512)
        denom = 2
        self.down4 = Down(512, 1024)
        self.bottleneck = BottleneckResBlock(1024)
        self.up1 = Up(1536, 512)
        self.up2 = Up(768, 256)
        self.up3 = Up(384, 128)
        self.up4 = Up(192, 64)
        self.outc = OutConv(64, n_classes)

    def forward(self, x):
        # Encoder path
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x5 = self.bottleneck(x5)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        logits = self.outc(x)
        return logits

# %%
model = UNet(n_channels=1, n_classes=4)
model.to(device)

pos_weight = torch.tensor([5.0], device=device)
criterion = CombinedLoss(alpha=0.3)
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
num_epochs = 1000

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode.
    train_loss = 0.0

    for inputs, targets in train_loader:

        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        # Move the data to the proper device.
        inputs = inputs.to(device)
        targets = targets.to(device)

        # do the training stuff
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        # Accumulate the loss for this batch.
        train_loss += loss.item() * inputs.size(0)

    # Compute average training loss.
    train_loss /= len(train_loader.dataset)
    print(f"Epoch {epoch+1}/{num_epochs} - Training Loss: {train_loss:.4f}")
# Out:
# Epoch 1/1000 - Training Loss: 0.8308
# Epoch 2/1000 - Training Loss: 0.6989
# Epoch 3/1000 - Training Loss: 0.6137
# Epoch 4/1000 - Training Loss: 0.5455
# Epoch 5/1000 - Training Loss: 0.4835
# Epoch 6/1000 - Training Loss: 0.4128
# Epoch 7/1000 - Training Loss: 0.3546
# Epoch 8/1000 - Training Loss: 0.3237
# Epoch 9/1000 - Training Loss: 0.2951
# Epoch 10/1000 - Training Loss: 0.2824
# Epoch 11/1000 - Training Loss: 0.2807
# Epoch 12/1000 - Training Loss: 0.2635
# Epoch 13/1000 - Training Loss: 0.2643
# Epoch 14/1000 - Training Loss: 0.2366
# Epoch 15/1000 - Training Loss: 0.2109
# Epoch 16/1000 - Training Loss: 0.2124
# Epoch 17/1000 - Training Loss: 0.1951
# Epoch 18/1000 - Training Loss: 0.1980
# Epoch 19/1000 - Training Loss: 0.1923
# Epoch 20/1000 - Training Loss: 0.1894
# Epoch 21/1000 - Training Loss: 0.1862
# Epoch 22/1000 - Training Loss: 0.2096
# Epoch 23/1000 - Training Loss: 0.1952
# Epoch 24/1000 - Training Loss: 0.1901
# Epoch 25/1000 - Training Loss: 0.1866
# Epoch 26/1000 - Training Loss: 0.1754
# Epoch 27/1000 - Training Loss: 0.1794
# Epoch 28/1000 - Training Loss: 0.1788
# Epoch 29/1000 - Training Loss: 0.1672
# Epoch 30/1000 - Training Loss: 0.1737
# Epoch 31/1000 - Training Loss: 0.1788
# Epoch 32/1000 - Training Loss: 0.1749
# Epoch 33/1000 - Training Loss: 0.1678
# Epoch 34/1000 - Training Loss: 0.1726
# Epoch 35/1000 - Training Loss: 0.1711
# Epoch 36/1000 - Training Loss: 0.1657
# Epoch 37/1000 - Training Loss: 0.1718
# Epoch 38/1000 - Training Loss: 0.1682
# Epoch 39/1000 - Training Loss: 0.1625
# Epoch 40/1000 - Training Loss: 0.1651
# Epoch 41/1000 - Training Loss: 0.1662
# Epoch 42/1000 - Training Loss: 0.1568
# Epoch 43/1000 - Training Loss: 0.1659
# Epoch 44/1000 - Training Loss: 0.1604
# Epoch 45/1000 - Training Loss: 0.1598
# Epoch 46/1000 - Training Loss: 0.1604
# Epoch 47/1000 - Training Loss: 0.1698
# Epoch 48/1000 - Training Loss: 0.1641
# Epoch 49/1000 - Training Loss: 0.1655
# Epoch 50/1000 - Training Loss: 0.1581
# Epoch 51/1000 - Training Loss: 0.1608
# Epoch 52/1000 - Training Loss: 0.1583
# Epoch 53/1000 - Training Loss: 0.1579
# Epoch 54/1000 - Training Loss: 0.1567
# Epoch 55/1000 - Training Loss: 0.1589
# Epoch 56/1000 - Training Loss: 0.1540
# Epoch 57/1000 - Training Loss: 0.1521
# Epoch 58/1000 - Training Loss: 0.1559
# Epoch 59/1000 - Training Loss: 0.1546
# Epoch 60/1000 - Training Loss: 0.1541
# Epoch 61/1000 - Training Loss: 0.1435
# Epoch 62/1000 - Training Loss: 0.1545
# Epoch 63/1000 - Training Loss: 0.1522
# Epoch 64/1000 - Training Loss: 0.1513
# Epoch 65/1000 - Training Loss: 0.1591
# Epoch 66/1000 - Training Loss: 0.1593
# Epoch 67/1000 - Training Loss: 0.1524
# Epoch 68/1000 - Training Loss: 0.1626
# Epoch 69/1000 - Training Loss: 0.1579
# Epoch 70/1000 - Training Loss: 0.1539
# Epoch 71/1000 - Training Loss: 0.1489
# Epoch 72/1000 - Training Loss: 0.1472
# Epoch 73/1000 - Training Loss: 0.1457
# Epoch 74/1000 - Training Loss: 0.1434
# Epoch 75/1000 - Training Loss: 0.1431
# Epoch 76/1000 - Training Loss: 0.1458
# Epoch 77/1000 - Training Loss: 0.1479
# Epoch 78/1000 - Training Loss: 0.1417
# Epoch 79/1000 - Training Loss: 0.1442
# Epoch 80/1000 - Training Loss: 0.1493
# Epoch 81/1000 - Training Loss: 0.1470
# Epoch 82/1000 - Training Loss: 0.1504
# Epoch 83/1000 - Training Loss: 0.1380
# Epoch 84/1000 - Training Loss: 0.1296
# Epoch 85/1000 - Training Loss: 0.1263
# Epoch 86/1000 - Training Loss: 0.1173
# Epoch 87/1000 - Training Loss: 0.1095
# Epoch 88/1000 - Training Loss: 0.1068
# Epoch 89/1000 - Training Loss: 0.1049
# Epoch 90/1000 - Training Loss: 0.1032
# Epoch 91/1000 - Training Loss: 0.0893
# Epoch 92/1000 - Training Loss: 0.0907
# Epoch 93/1000 - Training Loss: 0.0898
# Epoch 94/1000 - Training Loss: 0.0846
# Epoch 95/1000 - Training Loss: 0.0824
# Epoch 96/1000 - Training Loss: 0.0809
# Epoch 97/1000 - Training Loss: 0.0795
# Epoch 98/1000 - Training Loss: 0.0777
# Epoch 99/1000 - Training Loss: 0.0763
# Epoch 100/1000 - Training Loss: 0.0689
# Epoch 101/1000 - Training Loss: 0.0655
# Epoch 102/1000 - Training Loss: 0.0667
# Epoch 103/1000 - Training Loss: 0.0616
# Epoch 104/1000 - Training Loss: 0.0649
# Epoch 105/1000 - Training Loss: 0.0632
# Epoch 106/1000 - Training Loss: 0.0587
# Epoch 107/1000 - Training Loss: 0.0619
# Epoch 108/1000 - Training Loss: 0.0734
# Epoch 109/1000 - Training Loss: 0.0597
# Epoch 110/1000 - Training Loss: 0.0588
# Epoch 111/1000 - Training Loss: 0.0530
# Epoch 112/1000 - Training Loss: 0.0564
# Epoch 113/1000 - Training Loss: 0.0528
# Epoch 114/1000 - Training Loss: 0.0524
# Epoch 115/1000 - Training Loss: 0.0490
# Epoch 116/1000 - Training Loss: 0.0513
# Epoch 117/1000 - Training Loss: 0.0495
# Epoch 118/1000 - Training Loss: 0.0520
# Epoch 119/1000 - Training Loss: 0.0501
# Epoch 120/1000 - Training Loss: 0.0464
# Epoch 121/1000 - Training Loss: 0.0474
# Epoch 122/1000 - Training Loss: 0.0457
# Epoch 123/1000 - Training Loss: 0.0424
# Epoch 124/1000 - Training Loss: 0.0416
# Epoch 125/1000 - Training Loss: 0.0431
# Epoch 126/1000 - Training Loss: 0.0413
# Epoch 127/1000 - Training Loss: 0.0402
# Epoch 128/1000 - Training Loss: 0.0398
# Epoch 129/1000 - Training Loss: 0.0398
# Epoch 130/1000 - Training Loss: 0.0458
# Epoch 131/1000 - Training Loss: 0.0439
# Epoch 132/1000 - Training Loss: 0.0391
# Epoch 133/1000 - Training Loss: 0.0379
# Epoch 134/1000 - Training Loss: 0.0357
# Epoch 135/1000 - Training Loss: 0.0365
# Epoch 136/1000 - Training Loss: 0.0404
# Epoch 137/1000 - Training Loss: 0.0360
# Epoch 138/1000 - Training Loss: 0.0429
# Epoch 139/1000 - Training Loss: 0.0373
# Epoch 140/1000 - Training Loss: 0.0366
# Epoch 141/1000 - Training Loss: 0.0339
# Epoch 142/1000 - Training Loss: 0.0318
# Epoch 143/1000 - Training Loss: 0.0301
# Epoch 144/1000 - Training Loss: 0.0308
# Epoch 145/1000 - Training Loss: 0.0315
# Epoch 146/1000 - Training Loss: 0.0330
# Epoch 147/1000 - Training Loss: 0.0357
# Epoch 148/1000 - Training Loss: 0.0346
# Epoch 149/1000 - Training Loss: 0.0350
# Epoch 150/1000 - Training Loss: 0.0374
# Epoch 151/1000 - Training Loss: 0.0333
# Epoch 152/1000 - Training Loss: 0.0291
# Epoch 153/1000 - Training Loss: 0.0288
# Epoch 154/1000 - Training Loss: 0.0286
# Epoch 155/1000 - Training Loss: 0.0307
# Epoch 156/1000 - Training Loss: 0.0381
# Epoch 157/1000 - Training Loss: 0.0277
# Epoch 158/1000 - Training Loss: 0.0303
# Epoch 159/1000 - Training Loss: 0.0361
# Epoch 160/1000 - Training Loss: 0.0307
# Epoch 161/1000 - Training Loss: 0.0353
# Epoch 162/1000 - Training Loss: 0.0275
# Epoch 163/1000 - Training Loss: 0.0313
# Epoch 164/1000 - Training Loss: 0.0280
# Epoch 165/1000 - Training Loss: 0.0260
# Epoch 166/1000 - Training Loss: 0.0250
# Epoch 167/1000 - Training Loss: 0.0268
# Epoch 168/1000 - Training Loss: 0.0303
# Epoch 169/1000 - Training Loss: 0.0292
# Epoch 170/1000 - Training Loss: 0.0300
# Epoch 171/1000 - Training Loss: 0.0320
# Epoch 172/1000 - Training Loss: 0.0272
# Epoch 173/1000 - Training Loss: 0.0278
# Epoch 174/1000 - Training Loss: 0.0239
# Epoch 175/1000 - Training Loss: 0.0229
# Epoch 176/1000 - Training Loss: 0.0223
# Epoch 177/1000 - Training Loss: 0.0264
# Epoch 178/1000 - Training Loss: 0.0233
# Epoch 179/1000 - Training Loss: 0.0287
# Epoch 180/1000 - Training Loss: 0.0228
# Epoch 181/1000 - Training Loss: 0.0252
# Epoch 182/1000 - Training Loss: 0.0269
# Epoch 183/1000 - Training Loss: 0.0233
# Epoch 184/1000 - Training Loss: 0.0254
# Epoch 185/1000 - Training Loss: 0.0248
# Epoch 186/1000 - Training Loss: 0.0211
# Epoch 187/1000 - Training Loss: 0.0233
# Epoch 188/1000 - Training Loss: 0.0228
# Epoch 189/1000 - Training Loss: 0.0327
# Epoch 190/1000 - Training Loss: 0.0232
# Epoch 191/1000 - Training Loss: 0.0248
# Epoch 192/1000 - Training Loss: 0.0265
# Epoch 193/1000 - Training Loss: 0.0231
# Epoch 194/1000 - Training Loss: 0.0214
# Epoch 195/1000 - Training Loss: 0.0250
# Epoch 196/1000 - Training Loss: 0.0253
# Epoch 197/1000 - Training Loss: 0.0202
# Epoch 198/1000 - Training Loss: 0.0230
# Epoch 199/1000 - Training Loss: 0.0229
# Epoch 200/1000 - Training Loss: 0.0242
# Epoch 201/1000 - Training Loss: 0.0188
# Epoch 202/1000 - Training Loss: 0.0225
# Epoch 203/1000 - Training Loss: 0.0223
# Epoch 204/1000 - Training Loss: 0.0230
# Epoch 205/1000 - Training Loss: 0.0241
# Epoch 206/1000 - Training Loss: 0.0222
# Epoch 207/1000 - Training Loss: 0.0199
# Epoch 208/1000 - Training Loss: 0.0195
# Epoch 209/1000 - Training Loss: 0.0206
# Epoch 210/1000 - Training Loss: 0.0239
# Epoch 211/1000 - Training Loss: 0.0192
# Epoch 212/1000 - Training Loss: 0.0182
# Epoch 213/1000 - Training Loss: 0.0193
# Epoch 214/1000 - Training Loss: 0.0171
# Epoch 215/1000 - Training Loss: 0.0228
# Epoch 216/1000 - Training Loss: 0.0250
# Epoch 217/1000 - Training Loss: 0.0193
# Epoch 218/1000 - Training Loss: 0.0203
# Epoch 219/1000 - Training Loss: 0.0189
# Epoch 220/1000 - Training Loss: 0.0335
# Epoch 221/1000 - Training Loss: 0.0203
# Epoch 222/1000 - Training Loss: 0.0198
# Epoch 223/1000 - Training Loss: 0.0201
# Epoch 224/1000 - Training Loss: 0.0204
# Epoch 225/1000 - Training Loss: 0.0218
# Epoch 226/1000 - Training Loss: 0.0169
# Epoch 227/1000 - Training Loss: 0.0227
# Epoch 228/1000 - Training Loss: 0.0228
# Epoch 229/1000 - Training Loss: 0.0172
# Epoch 230/1000 - Training Loss: 0.0186
# Epoch 231/1000 - Training Loss: 0.0165
# Epoch 232/1000 - Training Loss: 0.0174
# Epoch 233/1000 - Training Loss: 0.0185
# Epoch 234/1000 - Training Loss: 0.0177
# Epoch 235/1000 - Training Loss: 0.0218
# Epoch 236/1000 - Training Loss: 0.0180
# Epoch 237/1000 - Training Loss: 0.0200
# Epoch 238/1000 - Training Loss: 0.0173
# Epoch 239/1000 - Training Loss: 0.0182
# Epoch 240/1000 - Training Loss: 0.0179
# Epoch 241/1000 - Training Loss: 0.0162
# Epoch 242/1000 - Training Loss: 0.0179
# Epoch 243/1000 - Training Loss: 0.0179
# Epoch 244/1000 - Training Loss: 0.0171
# Epoch 245/1000 - Training Loss: 0.0167
# Epoch 246/1000 - Training Loss: 0.0167
# Epoch 247/1000 - Training Loss: 0.0152
# Epoch 248/1000 - Training Loss: 0.0211
# Epoch 249/1000 - Training Loss: 0.0186
# Epoch 250/1000 - Training Loss: 0.0207
# Epoch 251/1000 - Training Loss: 0.0178
# Epoch 252/1000 - Training Loss: 0.0171
# Epoch 253/1000 - Training Loss: 0.0178
# Epoch 254/1000 - Training Loss: 0.0179
# Epoch 255/1000 - Training Loss: 0.0165
# Epoch 256/1000 - Training Loss: 0.0169
# Epoch 257/1000 - Training Loss: 0.0181
# Epoch 258/1000 - Training Loss: 0.0177
# Epoch 259/1000 - Training Loss: 0.0149
# Epoch 260/1000 - Training Loss: 0.0154
# Epoch 261/1000 - Training Loss: 0.0148
# Epoch 262/1000 - Training Loss: 0.0195
# Epoch 263/1000 - Training Loss: 0.0159
# Epoch 264/1000 - Training Loss: 0.0159
# Epoch 265/1000 - Training Loss: 0.0155
# Epoch 266/1000 - Training Loss: 0.0181
# Epoch 267/1000 - Training Loss: 0.0173
# Epoch 268/1000 - Training Loss: 0.0144
# Epoch 269/1000 - Training Loss: 0.0169
# Epoch 270/1000 - Training Loss: 0.0175
# Epoch 271/1000 - Training Loss: 0.0159
# Epoch 272/1000 - Training Loss: 0.0136
# Epoch 273/1000 - Training Loss: 0.0164
# Epoch 274/1000 - Training Loss: 0.0166
# Epoch 275/1000 - Training Loss: 0.0191
# Epoch 276/1000 - Training Loss: 0.0227
# Epoch 277/1000 - Training Loss: 0.0177
# Epoch 278/1000 - Training Loss: 0.0154
# Epoch 279/1000 - Training Loss: 0.0179
# Epoch 280/1000 - Training Loss: 0.0170
# Epoch 281/1000 - Training Loss: 0.0163
# Epoch 282/1000 - Training Loss: 0.0114
# Epoch 283/1000 - Training Loss: 0.0147
# Epoch 284/1000 - Training Loss: 0.0146
# Epoch 285/1000 - Training Loss: 0.0158
# Epoch 286/1000 - Training Loss: 0.0169
# Epoch 287/1000 - Training Loss: 0.0181
# Epoch 288/1000 - Training Loss: 0.0142
# Epoch 289/1000 - Training Loss: 0.0148
# Epoch 290/1000 - Training Loss: 0.0158
# Epoch 291/1000 - Training Loss: 0.0172
# Epoch 292/1000 - Training Loss: 0.0129
# Epoch 293/1000 - Training Loss: 0.0132
# Epoch 294/1000 - Training Loss: 0.0177
# Epoch 295/1000 - Training Loss: 0.0178
# Epoch 296/1000 - Training Loss: 0.0137
# Epoch 297/1000 - Training Loss: 0.0153
# Epoch 298/1000 - Training Loss: 0.0130
# Epoch 299/1000 - Training Loss: 0.0142
# Epoch 300/1000 - Training Loss: 0.0157
# Epoch 301/1000 - Training Loss: 0.0135
# Epoch 302/1000 - Training Loss: 0.0161
# Epoch 303/1000 - Training Loss: 0.0119
# Epoch 304/1000 - Training Loss: 0.0148
# Epoch 305/1000 - Training Loss: 0.0138
# Epoch 306/1000 - Training Loss: 0.0158
# Epoch 307/1000 - Training Loss: 0.0131
# Epoch 308/1000 - Training Loss: 0.0140
# Epoch 309/1000 - Training Loss: 0.0109
# Epoch 310/1000 - Training Loss: 0.0125
# Epoch 311/1000 - Training Loss: 0.0143
# Epoch 312/1000 - Training Loss: 0.0123
# Epoch 313/1000 - Training Loss: 0.0140
# Epoch 314/1000 - Training Loss: 0.0121
# Epoch 315/1000 - Training Loss: 0.0125
# Epoch 316/1000 - Training Loss: 0.0136
# Epoch 317/1000 - Training Loss: 0.0119
# Epoch 318/1000 - Training Loss: 0.0131
# Epoch 319/1000 - Training Loss: 0.0118
# Epoch 320/1000 - Training Loss: 0.0121
# Epoch 321/1000 - Training Loss: 0.0120
# Epoch 322/1000 - Training Loss: 0.0126
# Epoch 323/1000 - Training Loss: 0.0134
# Epoch 324/1000 - Training Loss: 0.0128
# Epoch 325/1000 - Training Loss: 0.0131
# Epoch 326/1000 - Training Loss: 0.0134
# Epoch 327/1000 - Training Loss: 0.0111
# Epoch 328/1000 - Training Loss: 0.0103
# Epoch 329/1000 - Training Loss: 0.0103
# Epoch 330/1000 - Training Loss: 0.0119
# Epoch 331/1000 - Training Loss: 0.0111
# Epoch 332/1000 - Training Loss: 0.0165
# Epoch 333/1000 - Training Loss: 0.0102
# Epoch 334/1000 - Training Loss: 0.0122
# Epoch 335/1000 - Training Loss: 0.0137
# Epoch 336/1000 - Training Loss: 0.0114
# Epoch 337/1000 - Training Loss: 0.0141
# Epoch 338/1000 - Training Loss: 0.0171
# Epoch 339/1000 - Training Loss: 0.0178
# Epoch 340/1000 - Training Loss: 0.0130
# Epoch 341/1000 - Training Loss: 0.0129
# Epoch 342/1000 - Training Loss: 0.0117
# Epoch 343/1000 - Training Loss: 0.0154
# Epoch 344/1000 - Training Loss: 0.0122
# Epoch 345/1000 - Training Loss: 0.0107
# Epoch 346/1000 - Training Loss: 0.0128
# Epoch 347/1000 - Training Loss: 0.0146
# Epoch 348/1000 - Training Loss: 0.0113
# Epoch 349/1000 - Training Loss: 0.0117
# Epoch 350/1000 - Training Loss: 0.0109
# Epoch 351/1000 - Training Loss: 0.0120
# Epoch 352/1000 - Training Loss: 0.0117
# Epoch 353/1000 - Training Loss: 0.0086
# Epoch 354/1000 - Training Loss: 0.0129
# Epoch 355/1000 - Training Loss: 0.0135
# Epoch 356/1000 - Training Loss: 0.0154
# Epoch 357/1000 - Training Loss: 0.0128
# Epoch 358/1000 - Training Loss: 0.0137
# Epoch 359/1000 - Training Loss: 0.0121
# Epoch 360/1000 - Training Loss: 0.0101
# Epoch 361/1000 - Training Loss: 0.0172
# Epoch 362/1000 - Training Loss: 0.0118
# Epoch 363/1000 - Training Loss: 0.0108
# Epoch 364/1000 - Training Loss: 0.0087
# Epoch 365/1000 - Training Loss: 0.0101
# Epoch 366/1000 - Training Loss: 0.0112
# Epoch 367/1000 - Training Loss: 0.0095
# Epoch 368/1000 - Training Loss: 0.0128
# Epoch 369/1000 - Training Loss: 0.0121
# Epoch 370/1000 - Training Loss: 0.0152
# Epoch 371/1000 - Training Loss: 0.0098
# Epoch 372/1000 - Training Loss: 0.0125
# Epoch 373/1000 - Training Loss: 0.0130
# Epoch 374/1000 - Training Loss: 0.0117
# Epoch 375/1000 - Training Loss: 0.0113
# Epoch 376/1000 - Training Loss: 0.0134
# Epoch 377/1000 - Training Loss: 0.0103
# Epoch 378/1000 - Training Loss: 0.0120
# Epoch 379/1000 - Training Loss: 0.0093
# Epoch 380/1000 - Training Loss: 0.0109
# Epoch 381/1000 - Training Loss: 0.0094
# Epoch 382/1000 - Training Loss: 0.0144
# Epoch 383/1000 - Training Loss: 0.0109
# Epoch 384/1000 - Training Loss: 0.0090
# Epoch 385/1000 - Training Loss: 0.0107
# Epoch 386/1000 - Training Loss: 0.0115
# Epoch 387/1000 - Training Loss: 0.0098
# Epoch 388/1000 - Training Loss: 0.0110
# Epoch 389/1000 - Training Loss: 0.0171
# Epoch 390/1000 - Training Loss: 0.0121
# Epoch 391/1000 - Training Loss: 0.0097
# Epoch 392/1000 - Training Loss: 0.0100
# Epoch 393/1000 - Training Loss: 0.0154
# Epoch 394/1000 - Training Loss: 0.0112
# Epoch 395/1000 - Training Loss: 0.0156
# Epoch 396/1000 - Training Loss: 0.0211
# Epoch 397/1000 - Training Loss: 0.0310
# Epoch 398/1000 - Training Loss: 0.0161
# Epoch 399/1000 - Training Loss: 0.0129
# Epoch 400/1000 - Training Loss: 0.0135
# Epoch 401/1000 - Training Loss: 0.0166
# Epoch 402/1000 - Training Loss: 0.0263
# Epoch 403/1000 - Training Loss: 0.0210
# Epoch 404/1000 - Training Loss: 0.0239
# Epoch 405/1000 - Training Loss: 0.0141
# Epoch 406/1000 - Training Loss: 0.0345
# Epoch 407/1000 - Training Loss: 0.0314
# Epoch 408/1000 - Training Loss: 0.0254
# Epoch 409/1000 - Training Loss: 0.0343
# Epoch 410/1000 - Training Loss: 0.0259
# Epoch 411/1000 - Training Loss: 0.0298
# Epoch 412/1000 - Training Loss: 0.0203
# Epoch 413/1000 - Training Loss: 0.0186
# Epoch 414/1000 - Training Loss: 0.0303
# Epoch 415/1000 - Training Loss: 0.0183
# Epoch 416/1000 - Training Loss: 0.0168
# Epoch 417/1000 - Training Loss: 0.0200
# Epoch 418/1000 - Training Loss: 0.0349
# Epoch 419/1000 - Training Loss: 0.0228
# Epoch 420/1000 - Training Loss: 0.0221
# Epoch 421/1000 - Training Loss: 0.0207
# Epoch 422/1000 - Training Loss: 0.0155
# Epoch 423/1000 - Training Loss: 0.0170
# Epoch 424/1000 - Training Loss: 0.0179
# Epoch 425/1000 - Training Loss: 0.0166
# Epoch 426/1000 - Training Loss: 0.0336
# Epoch 427/1000 - Training Loss: 0.0263
# Epoch 428/1000 - Training Loss: 0.0227
# Epoch 429/1000 - Training Loss: 0.0279
# Epoch 430/1000 - Training Loss: 0.0350
# Epoch 431/1000 - Training Loss: 0.0231
# Epoch 432/1000 - Training Loss: 0.0170
# Epoch 433/1000 - Training Loss: 0.0395
# Epoch 434/1000 - Training Loss: 0.0269
# Epoch 435/1000 - Training Loss: 0.0220
# Epoch 436/1000 - Training Loss: 0.0226
# Epoch 437/1000 - Training Loss: 0.0184
# Epoch 438/1000 - Training Loss: 0.0139
# Epoch 439/1000 - Training Loss: 0.0170
# Epoch 440/1000 - Training Loss: 0.0149
# Epoch 441/1000 - Training Loss: 0.0122
# Epoch 442/1000 - Training Loss: 0.0118
# Epoch 443/1000 - Training Loss: 0.0134
# Epoch 444/1000 - Training Loss: 0.0102
# Epoch 445/1000 - Training Loss: 0.0099
# Epoch 446/1000 - Training Loss: 0.0114
# Epoch 447/1000 - Training Loss: 0.0097
# Epoch 448/1000 - Training Loss: 0.0142
# Epoch 449/1000 - Training Loss: 0.0375
# Epoch 450/1000 - Training Loss: 0.0205
# Epoch 451/1000 - Training Loss: 0.0160
# Epoch 452/1000 - Training Loss: 0.0195
# Epoch 453/1000 - Training Loss: 0.0263
# Epoch 454/1000 - Training Loss: 0.0240
# Epoch 455/1000 - Training Loss: 0.0266
# Epoch 456/1000 - Training Loss: 0.0262
# Epoch 457/1000 - Training Loss: 0.0213
# Epoch 458/1000 - Training Loss: 0.0160
# Epoch 459/1000 - Training Loss: 0.0153
# Epoch 460/1000 - Training Loss: 0.0127
# Epoch 461/1000 - Training Loss: 0.0147
# Epoch 462/1000 - Training Loss: 0.0135
# Epoch 463/1000 - Training Loss: 0.0164
# Epoch 464/1000 - Training Loss: 0.0183
# Epoch 465/1000 - Training Loss: 0.0140
# Epoch 466/1000 - Training Loss: 0.0119
# Epoch 467/1000 - Training Loss: 0.0146
# Epoch 468/1000 - Training Loss: 0.0202
# Epoch 469/1000 - Training Loss: 0.0223
# Epoch 470/1000 - Training Loss: 0.0242
# Epoch 471/1000 - Training Loss: 0.0177
# Epoch 472/1000 - Training Loss: 0.0131
# Epoch 473/1000 - Training Loss: 0.0134
# Epoch 474/1000 - Training Loss: 0.0106
# Epoch 475/1000 - Training Loss: 0.0098
# Epoch 476/1000 - Training Loss: 0.0334
# Epoch 477/1000 - Training Loss: 0.0232
# Epoch 478/1000 - Training Loss: 0.0181
# Epoch 479/1000 - Training Loss: 0.0146
# Epoch 480/1000 - Training Loss: 0.0400
# Epoch 481/1000 - Training Loss: 0.0209
# Epoch 482/1000 - Training Loss: 0.0185
# Epoch 483/1000 - Training Loss: 0.0143
# Epoch 484/1000 - Training Loss: 0.0127
# Epoch 485/1000 - Training Loss: 0.0125
# Epoch 486/1000 - Training Loss: 0.0116
# Epoch 487/1000 - Training Loss: 0.0111
# Epoch 488/1000 - Training Loss: 0.0272
# Epoch 489/1000 - Training Loss: 0.0254
# Epoch 490/1000 - Training Loss: 0.0251
# Epoch 491/1000 - Training Loss: 0.0163
# Epoch 492/1000 - Training Loss: 0.0144
# Epoch 493/1000 - Training Loss: 0.0154
# Epoch 494/1000 - Training Loss: 0.0129
# Epoch 495/1000 - Training Loss: 0.0128
# Epoch 496/1000 - Training Loss: 0.0120
# Epoch 497/1000 - Training Loss: 0.0098
# Epoch 498/1000 - Training Loss: 0.0097
# Epoch 499/1000 - Training Loss: 0.0094
# Epoch 500/1000 - Training Loss: 0.0161
# Epoch 501/1000 - Training Loss: 0.0194
# Epoch 502/1000 - Training Loss: 0.0133
# Epoch 503/1000 - Training Loss: 0.0301
# Epoch 504/1000 - Training Loss: 0.0253
# Epoch 505/1000 - Training Loss: 0.0223
# Epoch 506/1000 - Training Loss: 0.0145
# Epoch 507/1000 - Training Loss: 0.0160
# Epoch 508/1000 - Training Loss: 0.0119
# Epoch 509/1000 - Training Loss: 0.0122
# Epoch 510/1000 - Training Loss: 0.0109
# Epoch 511/1000 - Training Loss: 0.0098
# Epoch 512/1000 - Training Loss: 0.0123
# Epoch 513/1000 - Training Loss: 0.0348
# Epoch 514/1000 - Training Loss: 0.0331
# Epoch 515/1000 - Training Loss: 0.0309
# Epoch 516/1000 - Training Loss: 0.0199
# Epoch 517/1000 - Training Loss: 0.0201
# Epoch 518/1000 - Training Loss: 0.0359
# Epoch 519/1000 - Training Loss: 0.0187
# Epoch 520/1000 - Training Loss: 0.0170
# Epoch 521/1000 - Training Loss: 0.0143
# Epoch 522/1000 - Training Loss: 0.0128
# Epoch 523/1000 - Training Loss: 0.0135
# Epoch 524/1000 - Training Loss: 0.0132
# Epoch 525/1000 - Training Loss: 0.0110
# Epoch 526/1000 - Training Loss: 0.0101
# Epoch 527/1000 - Training Loss: 0.0114
# Epoch 528/1000 - Training Loss: 0.0138
# Epoch 529/1000 - Training Loss: 0.0156
# Epoch 530/1000 - Training Loss: 0.0111
# Epoch 531/1000 - Training Loss: 0.0111
# Epoch 532/1000 - Training Loss: 0.0216
# Epoch 533/1000 - Training Loss: 0.0318
# Epoch 534/1000 - Training Loss: 0.0266
# Epoch 535/1000 - Training Loss: 0.0233
# Epoch 536/1000 - Training Loss: 0.0248
# Epoch 537/1000 - Training Loss: 0.0262
# Epoch 538/1000 - Training Loss: 0.0167
# Epoch 539/1000 - Training Loss: 0.0138
# Epoch 540/1000 - Training Loss: 0.0134
# Epoch 541/1000 - Training Loss: 0.0110
# Epoch 542/1000 - Training Loss: 0.0115
# Epoch 543/1000 - Training Loss: 0.0202
# Epoch 544/1000 - Training Loss: 0.0133
# Epoch 545/1000 - Training Loss: 0.0144
# Epoch 546/1000 - Training Loss: 0.0108
# Epoch 547/1000 - Training Loss: 0.0102
# Epoch 548/1000 - Training Loss: 0.0190
# Epoch 549/1000 - Training Loss: 0.0221
# Epoch 550/1000 - Training Loss: 0.0471
# Epoch 551/1000 - Training Loss: 0.0266
# Epoch 552/1000 - Training Loss: 0.0200
# Epoch 553/1000 - Training Loss: 0.0273
# Epoch 554/1000 - Training Loss: 0.0241
# Epoch 555/1000 - Training Loss: 0.0234
# Epoch 556/1000 - Training Loss: 0.0182
# Epoch 557/1000 - Training Loss: 0.0178
# Epoch 558/1000 - Training Loss: 0.0144
# Epoch 559/1000 - Training Loss: 0.0292
# Epoch 560/1000 - Training Loss: 0.0292
# Epoch 561/1000 - Training Loss: 0.0450
# Epoch 562/1000 - Training Loss: 0.0238
# Epoch 563/1000 - Training Loss: 0.0335
# Epoch 564/1000 - Training Loss: 0.0393
# Epoch 565/1000 - Training Loss: 0.0259
# Epoch 566/1000 - Training Loss: 0.0208
# Epoch 567/1000 - Training Loss: 0.0340
# Epoch 568/1000 - Training Loss: 0.0220
# Epoch 569/1000 - Training Loss: 0.0216
# Epoch 570/1000 - Training Loss: 0.0163
# Epoch 571/1000 - Training Loss: 0.0164
# Epoch 572/1000 - Training Loss: 0.0214
# Epoch 573/1000 - Training Loss: 0.0246
# Epoch 574/1000 - Training Loss: 0.0224
# Epoch 575/1000 - Training Loss: 0.0191
# Epoch 576/1000 - Training Loss: 0.0157
# Epoch 577/1000 - Training Loss: 0.0125
# Epoch 578/1000 - Training Loss: 0.0128
# Epoch 579/1000 - Training Loss: 0.0112
# Epoch 580/1000 - Training Loss: 0.0129
# Epoch 581/1000 - Training Loss: 0.0127
# Epoch 582/1000 - Training Loss: 0.0122
# Epoch 583/1000 - Training Loss: 0.0111
# Epoch 584/1000 - Training Loss: 0.0096
# Epoch 585/1000 - Training Loss: 0.0124
# Epoch 586/1000 - Training Loss: 0.0109
# Epoch 587/1000 - Training Loss: 0.0107
# Epoch 588/1000 - Training Loss: 0.0099
# Epoch 589/1000 - Training Loss: 0.0092
# Epoch 590/1000 - Training Loss: 0.0154
# Epoch 591/1000 - Training Loss: 0.0345
# Epoch 592/1000 - Training Loss: 0.0188
# Epoch 593/1000 - Training Loss: 0.0152
# Epoch 594/1000 - Training Loss: 0.0143
# Epoch 595/1000 - Training Loss: 0.0203
# Epoch 596/1000 - Training Loss: 0.0221
# Epoch 597/1000 - Training Loss: 0.0248
# Epoch 598/1000 - Training Loss: 0.0279
# Epoch 599/1000 - Training Loss: 0.0386
# Epoch 600/1000 - Training Loss: 0.0255
# Epoch 601/1000 - Training Loss: 0.0324
# Epoch 602/1000 - Training Loss: 0.0465
# Epoch 603/1000 - Training Loss: 0.0275
# Epoch 604/1000 - Training Loss: 0.0222
# Epoch 605/1000 - Training Loss: 0.0181
# Epoch 606/1000 - Training Loss: 0.0174
# Epoch 607/1000 - Training Loss: 0.0176
# Epoch 608/1000 - Training Loss: 0.0147
# Epoch 609/1000 - Training Loss: 0.0132
# Epoch 610/1000 - Training Loss: 0.0139
# Epoch 611/1000 - Training Loss: 0.0126
# Epoch 612/1000 - Training Loss: 0.0254
# Epoch 613/1000 - Training Loss: 0.0221
# Epoch 614/1000 - Training Loss: 0.0178
# Epoch 615/1000 - Training Loss: 0.0161
# Epoch 616/1000 - Training Loss: 0.0136
# Epoch 617/1000 - Training Loss: 0.0117
# Epoch 618/1000 - Training Loss: 0.0109
# Epoch 619/1000 - Training Loss: 0.0109
# Epoch 620/1000 - Training Loss: 0.0110
# Epoch 621/1000 - Training Loss: 0.0094
# Epoch 622/1000 - Training Loss: 0.0094
# Epoch 623/1000 - Training Loss: 0.0099
# Epoch 624/1000 - Training Loss: 0.0113
# Epoch 625/1000 - Training Loss: 0.0090
# Epoch 626/1000 - Training Loss: 0.0270
# Epoch 627/1000 - Training Loss: 0.0201
# Epoch 628/1000 - Training Loss: 0.0350
# Epoch 629/1000 - Training Loss: 0.0322
# Epoch 630/1000 - Training Loss: 0.0213
# Epoch 631/1000 - Training Loss: 0.0178
# Epoch 632/1000 - Training Loss: 0.0168
# Epoch 633/1000 - Training Loss: 0.0149
# Epoch 634/1000 - Training Loss: 0.0206
# Epoch 635/1000 - Training Loss: 0.0205
# Epoch 636/1000 - Training Loss: 0.0149
# Epoch 637/1000 - Training Loss: 0.0146
# Epoch 638/1000 - Training Loss: 0.0123
# Epoch 639/1000 - Training Loss: 0.0110
# Epoch 640/1000 - Training Loss: 0.0105
# Epoch 641/1000 - Training Loss: 0.0104
# Epoch 642/1000 - Training Loss: 0.0185
# Epoch 643/1000 - Training Loss: 0.0109
# Epoch 644/1000 - Training Loss: 0.0185
# Epoch 645/1000 - Training Loss: 0.0191
# Epoch 646/1000 - Training Loss: 0.0161
# Epoch 647/1000 - Training Loss: 0.0131
# Epoch 648/1000 - Training Loss: 0.0118
# Epoch 649/1000 - Training Loss: 0.0104
# Epoch 650/1000 - Training Loss: 0.0158
# Epoch 651/1000 - Training Loss: 0.0200
# Epoch 652/1000 - Training Loss: 0.0183
# Epoch 653/1000 - Training Loss: 0.0127
# Epoch 654/1000 - Training Loss: 0.0147
# Epoch 655/1000 - Training Loss: 0.0141
# Epoch 656/1000 - Training Loss: 0.0141
# Epoch 657/1000 - Training Loss: 0.0159
# Epoch 658/1000 - Training Loss: 0.0167
# Epoch 659/1000 - Training Loss: 0.0209
# Epoch 660/1000 - Training Loss: 0.0147
# Epoch 661/1000 - Training Loss: 0.0132
# Epoch 662/1000 - Training Loss: 0.0227
# Epoch 663/1000 - Training Loss: 0.0179
# Epoch 664/1000 - Training Loss: 0.0133
# Epoch 665/1000 - Training Loss: 0.0169
# Epoch 666/1000 - Training Loss: 0.0316
# Epoch 667/1000 - Training Loss: 0.0204
# Epoch 668/1000 - Training Loss: 0.0245
# Epoch 669/1000 - Training Loss: 0.0254
# Epoch 670/1000 - Training Loss: 0.0173
# Epoch 671/1000 - Training Loss: 0.0142
# Epoch 672/1000 - Training Loss: 0.0287
# Epoch 673/1000 - Training Loss: 0.0245
# Epoch 674/1000 - Training Loss: 0.0181
# Epoch 675/1000 - Training Loss: 0.0158
# Epoch 676/1000 - Training Loss: 0.0140
# Epoch 677/1000 - Training Loss: 0.0126
# Epoch 678/1000 - Training Loss: 0.0119
# Epoch 679/1000 - Training Loss: 0.0105
# Epoch 680/1000 - Training Loss: 0.0096
# Epoch 681/1000 - Training Loss: 0.0106
# Epoch 682/1000 - Training Loss: 0.0119
# Epoch 683/1000 - Training Loss: 0.0105
# Epoch 684/1000 - Training Loss: 0.0117
# Epoch 685/1000 - Training Loss: 0.0110
# Epoch 686/1000 - Training Loss: 0.0099
# Epoch 687/1000 - Training Loss: 0.0088
# Epoch 688/1000 - Training Loss: 0.0104
# Epoch 689/1000 - Training Loss: 0.0094
# Epoch 690/1000 - Training Loss: 0.0114
# Epoch 691/1000 - Training Loss: 0.0108
# Epoch 692/1000 - Training Loss: 0.0260
# Epoch 693/1000 - Training Loss: 0.0156
# Epoch 694/1000 - Training Loss: 0.0117
# Epoch 695/1000 - Training Loss: 0.0119
# Epoch 696/1000 - Training Loss: 0.0105
# Epoch 697/1000 - Training Loss: 0.0088
# Epoch 698/1000 - Training Loss: 0.0131
# Epoch 699/1000 - Training Loss: 0.0119
# Epoch 700/1000 - Training Loss: 0.0103
# Epoch 701/1000 - Training Loss: 0.0155
# Epoch 702/1000 - Training Loss: 0.0137
# Epoch 703/1000 - Training Loss: 0.0093
# Epoch 704/1000 - Training Loss: 0.0100
# Epoch 705/1000 - Training Loss: 0.0094
# Epoch 706/1000 - Training Loss: 0.0117
# Epoch 707/1000 - Training Loss: 0.0133
# Epoch 708/1000 - Training Loss: 0.0089
# Epoch 709/1000 - Training Loss: 0.0108
# Epoch 710/1000 - Training Loss: 0.0119
# Epoch 711/1000 - Training Loss: 0.0216
# Epoch 712/1000 - Training Loss: 0.0166
# Epoch 713/1000 - Training Loss: 0.0127
# Epoch 714/1000 - Training Loss: 0.0112
# Epoch 715/1000 - Training Loss: 0.0174
# Epoch 716/1000 - Training Loss: 0.0128
# Epoch 717/1000 - Training Loss: 0.0109
# Epoch 718/1000 - Training Loss: 0.0091
# Epoch 719/1000 - Training Loss: 0.0101
# Epoch 720/1000 - Training Loss: 0.0108
# Epoch 721/1000 - Training Loss: 0.0105
# Epoch 722/1000 - Training Loss: 0.0106
# Epoch 723/1000 - Training Loss: 0.0138
# Epoch 724/1000 - Training Loss: 0.0206
# Epoch 725/1000 - Training Loss: 0.0123
# Epoch 726/1000 - Training Loss: 0.0099
# Epoch 727/1000 - Training Loss: 0.0229
# Epoch 728/1000 - Training Loss: 0.0199
# Epoch 729/1000 - Training Loss: 0.0343
# Epoch 730/1000 - Training Loss: 0.0316
# Epoch 731/1000 - Training Loss: 0.0221
# Epoch 732/1000 - Training Loss: 0.0172
# Epoch 733/1000 - Training Loss: 0.0154
# Epoch 734/1000 - Training Loss: 0.0175
# Epoch 735/1000 - Training Loss: 0.0121
# Epoch 736/1000 - Training Loss: 0.0139
# Epoch 737/1000 - Training Loss: 0.0119
# Epoch 738/1000 - Training Loss: 0.0164
# Epoch 739/1000 - Training Loss: 0.0104
# Epoch 740/1000 - Training Loss: 0.0115
# Epoch 741/1000 - Training Loss: 0.0105
# Epoch 742/1000 - Training Loss: 0.0406
# Epoch 743/1000 - Training Loss: 0.0251
# Epoch 744/1000 - Training Loss: 0.0187
# Epoch 745/1000 - Training Loss: 0.0140
# Epoch 746/1000 - Training Loss: 0.0122
# Epoch 747/1000 - Training Loss: 0.0139
# Epoch 748/1000 - Training Loss: 0.0158
# Epoch 749/1000 - Training Loss: 0.0129
# Epoch 750/1000 - Training Loss: 0.0106
# Epoch 751/1000 - Training Loss: 0.0099
# Epoch 752/1000 - Training Loss: 0.0094
# Epoch 753/1000 - Training Loss: 0.0227
# Epoch 754/1000 - Training Loss: 0.0342
# Epoch 755/1000 - Training Loss: 0.0228
# Epoch 756/1000 - Training Loss: 0.0182
# Epoch 757/1000 - Training Loss: 0.0348
# Epoch 758/1000 - Training Loss: 0.0432
# Epoch 759/1000 - Training Loss: 0.0389
# Epoch 760/1000 - Training Loss: 0.0273
# Epoch 761/1000 - Training Loss: 0.0217
# Epoch 762/1000 - Training Loss: 0.0221
# Epoch 763/1000 - Training Loss: 0.0220
# Epoch 764/1000 - Training Loss: 0.0194
# Epoch 765/1000 - Training Loss: 0.0155
# Epoch 766/1000 - Training Loss: 0.0140
# Epoch 767/1000 - Training Loss: 0.0227
# Epoch 768/1000 - Training Loss: 0.0300
# Epoch 769/1000 - Training Loss: 0.0370
# Epoch 770/1000 - Training Loss: 0.0208
# Epoch 771/1000 - Training Loss: 0.0168
# Epoch 772/1000 - Training Loss: 0.0154
# Epoch 773/1000 - Training Loss: 0.0150
# Epoch 774/1000 - Training Loss: 0.0138
# Epoch 775/1000 - Training Loss: 0.0117
# Epoch 776/1000 - Training Loss: 0.0119
# Epoch 777/1000 - Training Loss: 0.0124
# Epoch 778/1000 - Training Loss: 0.0113
# Epoch 779/1000 - Training Loss: 0.0103
# Epoch 780/1000 - Training Loss: 0.0111
# Epoch 781/1000 - Training Loss: 0.0094
# Epoch 782/1000 - Training Loss: 0.0108
# Epoch 783/1000 - Training Loss: 0.0210
# Epoch 784/1000 - Training Loss: 0.0151
# Epoch 785/1000 - Training Loss: 0.0335
# Epoch 786/1000 - Training Loss: 0.0471
# Epoch 787/1000 - Training Loss: 0.0292
# Epoch 788/1000 - Training Loss: 0.0222
# Epoch 789/1000 - Training Loss: 0.0193
# Epoch 790/1000 - Training Loss: 0.0173
# Epoch 791/1000 - Training Loss: 0.0141
# Epoch 792/1000 - Training Loss: 0.0138
# Epoch 793/1000 - Training Loss: 0.0139
# Epoch 794/1000 - Training Loss: 0.0112
# Epoch 795/1000 - Training Loss: 0.0121
# Epoch 796/1000 - Training Loss: 0.0109
# Epoch 797/1000 - Training Loss: 0.0114
# Epoch 798/1000 - Training Loss: 0.0099
# Epoch 799/1000 - Training Loss: 0.0163
# Epoch 800/1000 - Training Loss: 0.0114
# Epoch 801/1000 - Training Loss: 0.0142
# Epoch 802/1000 - Training Loss: 0.0177
# Epoch 803/1000 - Training Loss: 0.0116
# Epoch 804/1000 - Training Loss: 0.0125
# Epoch 805/1000 - Training Loss: 0.0118
# Epoch 806/1000 - Training Loss: 0.0169
# Epoch 807/1000 - Training Loss: 0.0215
# Epoch 808/1000 - Training Loss: 0.0137
# Epoch 809/1000 - Training Loss: 0.0133
# Epoch 810/1000 - Training Loss: 0.0150
# Epoch 811/1000 - Training Loss: 0.0179
# Epoch 812/1000 - Training Loss: 0.0127
# Epoch 813/1000 - Training Loss: 0.0122
# Epoch 814/1000 - Training Loss: 0.0095
# Epoch 815/1000 - Training Loss: 0.0085
# Epoch 816/1000 - Training Loss: 0.0090
# Epoch 817/1000 - Training Loss: 0.0087
# Epoch 818/1000 - Training Loss: 0.0076
# Epoch 819/1000 - Training Loss: 0.0093
# Epoch 820/1000 - Training Loss: 0.0089
# Epoch 821/1000 - Training Loss: 0.0087
# Epoch 822/1000 - Training Loss: 0.0095
# Epoch 823/1000 - Training Loss: 0.0080
# Epoch 824/1000 - Training Loss: 0.0104
# Epoch 825/1000 - Training Loss: 0.0138
# Epoch 826/1000 - Training Loss: 0.0127
# Epoch 827/1000 - Training Loss: 0.0178
# Epoch 828/1000 - Training Loss: 0.0110
# Epoch 829/1000 - Training Loss: 0.0221
# Epoch 830/1000 - Training Loss: 0.0225
# Epoch 831/1000 - Training Loss: 0.0143
# Epoch 832/1000 - Training Loss: 0.0116
# Epoch 833/1000 - Training Loss: 0.0104
# Epoch 834/1000 - Training Loss: 0.0126
# Epoch 835/1000 - Training Loss: 0.0087
# Epoch 836/1000 - Training Loss: 0.0099
# Epoch 837/1000 - Training Loss: 0.0096
# Epoch 838/1000 - Training Loss: 0.0079
# Epoch 839/1000 - Training Loss: 0.0090
# Epoch 840/1000 - Training Loss: 0.0184
# Epoch 841/1000 - Training Loss: 0.0126
# Epoch 842/1000 - Training Loss: 0.0091
# Epoch 843/1000 - Training Loss: 0.0086
# Epoch 844/1000 - Training Loss: 0.0075
# Epoch 845/1000 - Training Loss: 0.0338
# Epoch 846/1000 - Training Loss: 0.0284
# Epoch 847/1000 - Training Loss: 0.0202
# Epoch 848/1000 - Training Loss: 0.0147
# Epoch 849/1000 - Training Loss: 0.0127
# Epoch 850/1000 - Training Loss: 0.0164
# Epoch 851/1000 - Training Loss: 0.0194
# Epoch 852/1000 - Training Loss: 0.0269
# Epoch 853/1000 - Training Loss: 0.0172
# Epoch 854/1000 - Training Loss: 0.0160
# Epoch 855/1000 - Training Loss: 0.0121
# Epoch 856/1000 - Training Loss: 0.0120
# Epoch 857/1000 - Training Loss: 0.0121
# Epoch 858/1000 - Training Loss: 0.0145
# Epoch 859/1000 - Training Loss: 0.0220
# Epoch 860/1000 - Training Loss: 0.0234
# Epoch 861/1000 - Training Loss: 0.0156
# Epoch 862/1000 - Training Loss: 0.0132
# Epoch 863/1000 - Training Loss: 0.0126
# Epoch 864/1000 - Training Loss: 0.0099
# Epoch 865/1000 - Training Loss: 0.0123
# Epoch 866/1000 - Training Loss: 0.0111
# Epoch 867/1000 - Training Loss: 0.0088
# Epoch 868/1000 - Training Loss: 0.0197
# Epoch 869/1000 - Training Loss: 0.0317
# Epoch 870/1000 - Training Loss: 0.0217
# Epoch 871/1000 - Training Loss: 0.0154
# Epoch 872/1000 - Training Loss: 0.0140
# Epoch 873/1000 - Training Loss: 0.0158
# Epoch 874/1000 - Training Loss: 0.0275
# Epoch 875/1000 - Training Loss: 0.0299
# Epoch 876/1000 - Training Loss: 0.0222
# Epoch 877/1000 - Training Loss: 0.0152
# Epoch 878/1000 - Training Loss: 0.0142
# Epoch 879/1000 - Training Loss: 0.0147
# Epoch 880/1000 - Training Loss: 0.0109
# Epoch 881/1000 - Training Loss: 0.0123
# Epoch 882/1000 - Training Loss: 0.0234
# Epoch 883/1000 - Training Loss: 0.0164
# Epoch 884/1000 - Training Loss: 0.0127
# Epoch 885/1000 - Training Loss: 0.0126
# Epoch 886/1000 - Training Loss: 0.0147
# Epoch 887/1000 - Training Loss: 0.0130
# Epoch 888/1000 - Training Loss: 0.0100
# Epoch 889/1000 - Training Loss: 0.0086
# Epoch 890/1000 - Training Loss: 0.0189
# Epoch 891/1000 - Training Loss: 0.0160
# Epoch 892/1000 - Training Loss: 0.0143
# Epoch 893/1000 - Training Loss: 0.0143
# Epoch 894/1000 - Training Loss: 0.0112
# Epoch 895/1000 - Training Loss: 0.0092
# Epoch 896/1000 - Training Loss: 0.0122
# Epoch 897/1000 - Training Loss: 0.0096
# Epoch 898/1000 - Training Loss: 0.0081
# Epoch 899/1000 - Training Loss: 0.0169
# Epoch 900/1000 - Training Loss: 0.0286
# Epoch 901/1000 - Training Loss: 0.0256
# Epoch 902/1000 - Training Loss: 0.0170
# Epoch 903/1000 - Training Loss: 0.0209
# Epoch 904/1000 - Training Loss: 0.0202
# Epoch 905/1000 - Training Loss: 0.0236
# Epoch 906/1000 - Training Loss: 0.0196
# Epoch 907/1000 - Training Loss: 0.0180
# Epoch 908/1000 - Training Loss: 0.0144
# Epoch 909/1000 - Training Loss: 0.0155
# Epoch 910/1000 - Training Loss: 0.0133
# Epoch 911/1000 - Training Loss: 0.0113
# Epoch 912/1000 - Training Loss: 0.0100
# Epoch 913/1000 - Training Loss: 0.0103
# Epoch 914/1000 - Training Loss: 0.0093
# Epoch 915/1000 - Training Loss: 0.0128
# Epoch 916/1000 - Training Loss: 0.0175
# Epoch 917/1000 - Training Loss: 0.0130
# Epoch 918/1000 - Training Loss: 0.0128
# Epoch 919/1000 - Training Loss: 0.0116
# Epoch 920/1000 - Training Loss: 0.0175
# Epoch 921/1000 - Training Loss: 0.0241
# Epoch 922/1000 - Training Loss: 0.0207
# Epoch 923/1000 - Training Loss: 0.0167
# Epoch 924/1000 - Training Loss: 0.0147
# Epoch 925/1000 - Training Loss: 0.0133
# Epoch 926/1000 - Training Loss: 0.0109
# Epoch 927/1000 - Training Loss: 0.0102
# Epoch 928/1000 - Training Loss: 0.0102
# Epoch 929/1000 - Training Loss: 0.0113
# Epoch 930/1000 - Training Loss: 0.0086
# Epoch 931/1000 - Training Loss: 0.0183
# Epoch 932/1000 - Training Loss: 0.0120
# Epoch 933/1000 - Training Loss: 0.0089
# Epoch 934/1000 - Training Loss: 0.0260
# Epoch 935/1000 - Training Loss: 0.0173
# Epoch 936/1000 - Training Loss: 0.0118
# Epoch 937/1000 - Training Loss: 0.0145
# Epoch 938/1000 - Training Loss: 0.0108
# Epoch 939/1000 - Training Loss: 0.0090
# Epoch 940/1000 - Training Loss: 0.0086
# Epoch 941/1000 - Training Loss: 0.0167
# Epoch 942/1000 - Training Loss: 0.0258
# Epoch 943/1000 - Training Loss: 0.0303
# Epoch 944/1000 - Training Loss: 0.0221
# Epoch 945/1000 - Training Loss: 0.0166
# Epoch 946/1000 - Training Loss: 0.0142
# Epoch 947/1000 - Training Loss: 0.0114
# Epoch 948/1000 - Training Loss: 0.0104
# Epoch 949/1000 - Training Loss: 0.0098
# Epoch 950/1000 - Training Loss: 0.0288
# Epoch 951/1000 - Training Loss: 0.0168
# Epoch 952/1000 - Training Loss: 0.0126
# Epoch 953/1000 - Training Loss: 0.0116
# Epoch 954/1000 - Training Loss: 0.0107
# Epoch 955/1000 - Training Loss: 0.0105
# Epoch 956/1000 - Training Loss: 0.0211
# Epoch 957/1000 - Training Loss: 0.0343
# Epoch 958/1000 - Training Loss: 0.0295
# Epoch 959/1000 - Training Loss: 0.0228
# Epoch 960/1000 - Training Loss: 0.0173
# Epoch 961/1000 - Training Loss: 0.0165
# Epoch 962/1000 - Training Loss: 0.0140
# Epoch 963/1000 - Training Loss: 0.0246
# Epoch 964/1000 - Training Loss: 0.0195
# Epoch 965/1000 - Training Loss: 0.0145
# Epoch 966/1000 - Training Loss: 0.0126
# Epoch 967/1000 - Training Loss: 0.0129
# Epoch 968/1000 - Training Loss: 0.0122
# Epoch 969/1000 - Training Loss: 0.0119
# Epoch 970/1000 - Training Loss: 0.0107
# Epoch 971/1000 - Training Loss: 0.0176
# Epoch 972/1000 - Training Loss: 0.0168
# Epoch 973/1000 - Training Loss: 0.0116
# Epoch 974/1000 - Training Loss: 0.0253
# Epoch 975/1000 - Training Loss: 0.0166
# Epoch 976/1000 - Training Loss: 0.0172
# Epoch 977/1000 - Training Loss: 0.0201
# Epoch 978/1000 - Training Loss: 0.0207
# Epoch 979/1000 - Training Loss: 0.0166
# Epoch 980/1000 - Training Loss: 0.0352
# Epoch 981/1000 - Training Loss: 0.0189
# Epoch 982/1000 - Training Loss: 0.0245
# Epoch 983/1000 - Training Loss: 0.0181
# Epoch 984/1000 - Training Loss: 0.0241
# Epoch 985/1000 - Training Loss: 0.0214
# Epoch 986/1000 - Training Loss: 0.0169
# Epoch 987/1000 - Training Loss: 0.0138
# Epoch 988/1000 - Training Loss: 0.0168
# Epoch 989/1000 - Training Loss: 0.0181
# Epoch 990/1000 - Training Loss: 0.0144
# Epoch 991/1000 - Training Loss: 0.0125
# Epoch 992/1000 - Training Loss: 0.0453
# Epoch 993/1000 - Training Loss: 0.0290
# Epoch 994/1000 - Training Loss: 0.0333
# Epoch 995/1000 - Training Loss: 0.0224
# Epoch 996/1000 - Training Loss: 0.0189
# Epoch 997/1000 - Training Loss: 0.0180
# Epoch 998/1000 - Training Loss: 0.0161
# Epoch 999/1000 - Training Loss: 0.0138
# Epoch 1000/1000 - Training Loss: 0.0204

# %%
# save the model
torch.save(model.state_dict(), 'model_3000_100_a_v3.ai')

# %%
# load the model
model = UNet(n_channels=1, n_classes=4)
model.load_state_dict(torch.load('model_3000_100_a_v3.ai'))
model.to(device)
# Out:
# UNet(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down2): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down3): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down4): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (bottleneck): BottleneckResBlock(
#     (conv): Sequential(
#       (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Dropout2d(p=0.3, inplace=False)
#       (4): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (up1): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(1536, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up2): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up3): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up4): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (outc): OutConv(
#     (conv): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
# errors with: case133_day25_slice_0049, All of day 77
X, y = mrid["case139_day0_slice_0062"]
y[y != 0] = 1

display_image_with_mask(X.squeeze(), y)

X_pred = X.unsqueeze(0).to(device)
y_pred = model(X_pred)

y_pred = torch.argmax(y_pred, dim=1)
y_pred[y_pred != 0] = 1

y_print = y_pred.detach().cpu().numpy()
display_image_with_mask(X.squeeze(), y_print.squeeze())
